# %%
import pandas as pd
import fastf1 as f1
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import data_loader
import eda_utils

# %%
F1=data_loader.F1dataloader(2020,2024)
F1.load_year_data()
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (5.71 GB) C:\Users\divya\AppData\Local\Temp\fastf1
# events      WARNING 	Correcting user input 'Pre-Season Test 1' to 'Austrian Grand Prix'
# core           INFO 	Loading data for Austrian Grand Prix - Qualifying [v3.4.4]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['77', '44', '33', '4', '23', '11', '16', '55', '18', '3', '5', '10', '26', '31', '8', '20', '63', '99', '7', '6']
# events      WARNING 	Correcting user input 'Pre-Season Test 2' to 'Austrian Grand Prix'
# core           INFO 	Loading data for Austrian Grand Prix - Qualifying [v3.4.4]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# Laps data for Pre-Season Test 1 2020:
#                     Time Driver DriverNumber                LapTime  \
# 0 0 days 00:21:40.177000    BOT           77                    NaT
# 1 0 days 00:22:44.730000    BOT           77 0 days 00:01:04.553000
# 2 0 days 00:24:07.389000    BOT           77 0 days 00:01:22.659000
# 3 0 days 00:29:46.968000    BOT           77                    NaT
# 4 0 days 00:30:51.079000    BOT           77 0 days 00:01:04.111000
#
#    LapNumber  Stint             PitOutTime              PitInTime  \
# 0        1.0    1.0 0 days 00:20:11.180000                    NaT
# 1        2.0    1.0                    NaT                    NaT
# 2        3.0    1.0                    NaT 0 days 00:24:04.024000
# 3        4.0    2.0 0 days 00:28:18.500000                    NaT
# 4        5.0    2.0                    NaT                    NaT
#
#              Sector1Time            Sector2Time  ...           LapStartTime  \
# 0                    NaT 0 days 00:00:36.515000  ... 0 days 00:20:11.180000
# 1 0 days 00:00:16.353000 0 days 00:00:28.695000  ... 0 days 00:21:40.177000
# 2 0 days 00:00:19.381000 0 days 00:00:34.508000  ... 0 days 00:22:44.730000
# 3                    NaT 0 days 00:00:37.247000  ... 0 days 00:24:07.389000
# 4 0 days 00:00:16.204000 0 days 00:00:28.514000  ... 0 days 00:29:46.968000
#
#              LapStartDate TrackStatus Position  Deleted  DeletedReason  \
# 0 2020-07-04 13:08:01.509           1      NaN    False
# 1 2020-07-04 13:09:30.506           1      NaN    False
# 2 2020-07-04 13:10:35.059           1      NaN    False
# 3 2020-07-04 13:11:57.718           1      NaN    False
# 4 2020-07-04 13:17:37.297           1      NaN    False
#
#    FastF1Generated  IsAccurate  Year            gp_name
# 0            False       False  2020  Pre-Season Test 1
# 1            False        True  2020  Pre-Season Test 1
# 2            False       False  2020  Pre-Season Test 1
# 3            False       False  2020  Pre-Season Test 1
# 4            False        True  2020  Pre-Season Test 1
#
# [5 rows x 33 columns]
# Weather data for Pre-Season Test 1 2020:
#                     Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 0 0 days 00:00:47.829000     24.3      35.8     941.1     False       51.8
# 1 0 days 00:01:47.827000     24.5      36.2     941.1     False       52.4
# 2 0 days 00:02:47.843000     24.3      35.2     941.0     False       52.3
# 3 0 days 00:03:47.864000     24.0      36.2     940.9     False       52.3
# 4 0 days 00:04:47.866000     23.7      36.8     941.0     False       52.6
#
#    WindDirection  WindSpeed
# 0            261        1.2
# 1            223        0.6
# 2             15        0.7
# 3              6        1.9
# 4            281        1.2
# No valid data for Pre-Season Test 1 2020. Skipping.
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: 
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['77', '44', '33', '4', '23', '11', '16', '55', '18', '3', '5', '10', '26', '31', '8', '20', '63', '99', '7', '6']
# Laps data for Austrian Grand Prix 2020:
#                     Time Driver DriverNumber                LapTime  \
# 0 0 days 00:21:40.177000    BOT           77                    NaT
# 1 0 days 00:22:44.730000    BOT           77 0 days 00:01:04.553000
# 2 0 days 00:24:07.389000    BOT           77 0 days 00:01:22.659000
# 3 0 days 00:29:46.968000    BOT           77                    NaT
# 4 0 days 00:30:51.079000    BOT           77 0 days 00:01:04.111000
#
#    LapNumber  Stint             PitOutTime              PitInTime  \
# 0        1.0    1.0 0 days 00:20:11.180000                    NaT
# 1        2.0    1.0                    NaT                    NaT
# 2        3.0    1.0                    NaT 0 days 00:24:04.024000
# 3        4.0    2.0 0 days 00:28:18.500000                    NaT
# 4        5.0    2.0                    NaT                    NaT
#
#              Sector1Time            Sector2Time  ...           LapStartTime  \
# 0                    NaT 0 days 00:00:36.515000  ... 0 days 00:20:11.180000
# 1 0 days 00:00:16.353000 0 days 00:00:28.695000  ... 0 days 00:21:40.177000
# 2 0 days 00:00:19.381000 0 days 00:00:34.508000  ... 0 days 00:22:44.730000
# 3                    NaT 0 days 00:00:37.247000  ... 0 days 00:24:07.389000
# 4 0 days 00:00:16.204000 0 days 00:00:28.514000  ... 0 days 00:29:46.968000
#
#              LapStartDate TrackStatus Position  Deleted  DeletedReason  \
# 0 2020-07-04 13:08:01.509           1      NaN    False
# 1 2020-07-04 13:09:30.506           1      NaN    False
# 2 2020-07-04 13:10:35.059           1      NaN    False
# 3 2020-07-04 13:11:57.718           1      NaN    False
# 4 2020-07-04 13:17:37.297           1      NaN    False
#
#    FastF1Generated  IsAccurate  Year              gp_name
# 0            False       False  2020  Austrian Grand Prix
# 1            False        True  2020  Austrian Grand Prix
# 2            False       False  2020  Austrian Grand Prix
# 3            False       False  2020  Austrian Grand Prix
# 4            False        True  2020  Austrian Grand Prix
#
# [5 rows x 33 columns]
# Weather data for Austrian Grand Prix 2020:
#                     Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 0 0 days 00:00:47.829000     24.3      35.8     941.1     False       51.8
# 1 0 days 00:01:47.827000     24.5      36.2     941.1     False       52.4
# 2 0 days 00:02:47.843000     24.3      35.2     941.0     False       52.3
# 3 0 days 00:03:47.864000     24.0      36.2     940.9     False       52.3
# 4 0 days 00:04:47.866000     23.7      36.8     941.0     False       52.6
#
#    WindDirection  WindSpeed
# 0            261        1.2
# 1            223        0.6
# 2             15        0.7
# 3              6        1.9
# 4            281        1.2
# Processed DataFrame shape: (203, 25)
# Processed DataFrame shape: (203, 26)
# Processed DataFrame shape: (203, 27)
# Final shapes after filtering: [(149, 25), (149, 26), (149, 27)]
# Loaded qualifying data for Austrian Grand Prix 2020
# C:\Users\divya\Downloads\QueBridge\data_loader.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['LapTime'] = df['LapTime'].dt.total_seconds().astype(float).round(3)
# C:\Users\divya\Downloads\QueBridge\data_loader.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(subset=['Time'], keep='first', inplace=True)
# C:\Users\divya\Downloads\QueBridge\data_loader.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['LapTime'] = df['LapTime'].dt.total_seconds().astype(float).round(3)
# C:\Users\divya\Downloads\QueBridge\data_loader.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(subset=['Time'], keep='first', inplace=True)
# C:\Users\divya\Downloads\QueBridge\data_loader.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['LapTime'] = df['LapTime'].dt.total_seconds().astype(float).round(3)
# C:\Users\divya\Downloads\QueBridge\data_loader.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(subset=['Time'], keep='first', inplace=True)
# core           INFO 	Loading data for Styrian Grand Prix - Qualifying [v3.4.4]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# C:\Users\divya\anaconda3\Lib\site-packages\fastf1\core.py:1579: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<TimedeltaArray>
# ['0 days 01:00:39.414000']
# Length: 1, dtype: timedelta64[ns]' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   result.loc[mask, 'LapStartTime'] = result.loc[mask, 'PitOutTime']
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '55', '77', '31', '4', '23', '10', '3', '5', '16', '63', '18', '26', '20', '7', '11', '6', '99', '8']
# C:\Users\divya\Downloads\QueBridge\data_loader.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['LapTime'] = df['LapTime'].dt.total_seconds().astype(float).round(3)
# C:\Users\divya\Downloads\QueBridge\data_loader.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(subset=['Time'], keep='first', inplace=True)
# C:\Users\divya\Downloads\QueBridge\data_loader.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['LapTime'] = df['LapTime'].dt.total_seconds().astype(float).round(3)
# C:\Users\divya\Downloads\QueBridge\data_loader.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(subset=['Time'], keep='first', inplace=True)
# C:\Users\divya\Downloads\QueBridge\data_loader.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['LapTime'] = df['LapTime'].dt.total_seconds().astype(float).round(3)
# C:\Users\divya\Downloads\QueBridge\data_loader.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(subset=['Time'], keep='first', inplace=True)
# core           INFO 	Loading data for Hungarian Grand Prix - Qualifying [v3.4.4]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Laps data for Styrian Grand Prix 2020:
#                     Time Driver DriverNumber                LapTime  \
# 0 0 days 01:01:27.487000    HAM           44                    NaT
# 1 0 days 01:02:55.364000    HAM           44 0 days 00:01:27.877000
# 2 0 days 01:04:56.329000    HAM           44 0 days 00:02:00.965000
# 3 0 days 01:06:17.282000    HAM           44 0 days 00:01:20.953000
# 4 0 days 01:07:42.590000    HAM           44 0 days 00:01:25.308000
#
#    LapNumber  Stint             PitOutTime PitInTime            Sector1Time  \
# 0        1.0    1.0 0 days 00:59:36.220000       NaT                    NaT
# 1        2.0    1.0                    NaT       NaT 0 days 00:00:20.406000
# 2        3.0    1.0                    NaT       NaT 0 days 00:00:20.944000
# 3        4.0    1.0                    NaT       NaT 0 days 00:00:19.566000
# 4        5.0    1.0                    NaT       NaT 0 days 00:00:19.526000
#
#              Sector2Time  ...           LapStartTime            LapStartDate  \
# 0 0 days 00:00:47.221000  ... 0 days 00:59:36.220000 2020-07-11 13:46:23.839
# 1 0 days 00:00:38.668000  ... 0 days 01:01:27.487000 2020-07-11 13:48:15.106
# 2 0 days 00:01:04.385000  ... 0 days 01:02:55.364000 2020-07-11 13:49:42.983
# 3 0 days 00:00:36.137000  ... 0 days 01:04:56.329000 2020-07-11 13:51:43.948
# 4 0 days 00:00:36.282000  ... 0 days 01:06:17.282000 2020-07-11 13:53:04.901
#
#   TrackStatus Position  Deleted  DeletedReason  FastF1Generated  IsAccurate  \
# 0           1      NaN    False                           False       False
# 1           1      NaN    False                           False        True
# 2           1      NaN    False                           False        True
# 3           1      NaN    False                           False        True
# 4          12      NaN    False                           False        True
#
#    Year             gp_name
# 0  2020  Styrian Grand Prix
# 1  2020  Styrian Grand Prix
# 2  2020  Styrian Grand Prix
# 3  2020  Styrian Grand Prix
# 4  2020  Styrian Grand Prix
#
# [5 rows x 33 columns]
# Weather data for Styrian Grand Prix 2020:
#                     Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 0 0 days 00:00:31.322000     15.0      87.1     942.3      True       21.2
# 1 0 days 00:01:31.324000     15.0      87.1     942.3      True       21.2
# 2 0 days 00:02:31.316000     15.2      87.8     942.5      True       21.3
# 3 0 days 00:03:31.326000     15.3      88.0     942.6      True       21.1
# 4 0 days 00:04:31.323000     15.2      87.2     942.5      True       20.9
#
#    WindDirection  WindSpeed
# 0            264        1.4
# 1            264        1.4
# 2            274        1.7
# 3            250        1.5
# 4            262        1.8
# Processed DataFrame shape: (423, 25)
# Processed DataFrame shape: (423, 26)
# Processed DataFrame shape: (423, 27)
# Final shapes after filtering: [(314, 25), (314, 26), (314, 27)]
# Loaded qualifying data for Styrian Grand Prix 2020
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '18', '11', '5', '16', '33', '4', '55', '10', '3', '63', '23', '31', '6', '20', '26', '8', '99', '7']
# C:\Users\divya\Downloads\QueBridge\data_loader.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['LapTime'] = df['LapTime'].dt.total_seconds().astype(float).round(3)
# C:\Users\divya\Downloads\QueBridge\data_loader.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(subset=['Time'], keep='first', inplace=True)
# C:\Users\divya\Downloads\QueBridge\data_loader.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['LapTime'] = df['LapTime'].dt.total_seconds().astype(float).round(3)
# C:\Users\divya\Downloads\QueBridge\data_loader.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(subset=['Time'], keep='first', inplace=True)
# C:\Users\divya\Downloads\QueBridge\data_loader.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['LapTime'] = df['LapTime'].dt.total_seconds().astype(float).round(3)
# C:\Users\divya\Downloads\QueBridge\data_loader.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(subset=['Time'], keep='first', inplace=True)
# core           INFO 	Loading data for British Grand Prix - Qualifying [v3.4.4]
# Laps data for Hungarian Grand Prix 2020:
#                     Time Driver DriverNumber                LapTime  \
# 0 0 days 00:16:38.478000    HAM           44                    NaT
# 1 0 days 00:17:54.059000    HAM           44 0 days 00:01:15.581000
# 2 0 days 00:19:39.803000    HAM           44 0 days 00:01:45.744000
# 3 0 days 00:20:55.223000    HAM           44 0 days 00:01:15.420000
# 4 0 days 00:22:37.621000    HAM           44 0 days 00:01:42.398000
#
#    LapNumber  Stint             PitOutTime PitInTime            Sector1Time  \
# 0        1.0    1.0 0 days 00:15:06.678000       NaT                    NaT
# 1        2.0    1.0                    NaT       NaT 0 days 00:00:27.726000
# 2        3.0    1.0                    NaT       NaT 0 days 00:00:36.836000
# 3        4.0    1.0                    NaT       NaT 0 days 00:00:27.809000
# 4        5.0    1.0                    NaT       NaT 0 days 00:00:36.690000
#
#              Sector2Time  ...           LapStartTime            LapStartDate  \
# 0 0 days 00:00:29.812000  ... 0 days 00:15:06.678000 2020-07-18 13:00:06.880
# 1 0 days 00:00:26.497000  ... 0 days 00:16:38.478000 2020-07-18 13:01:38.680
# 2 0 days 00:00:40.288000  ... 0 days 00:17:54.059000 2020-07-18 13:02:54.261
# 3 0 days 00:00:26.340000  ... 0 days 00:19:39.803000 2020-07-18 13:04:40.005
# 4 0 days 00:00:41.743000  ... 0 days 00:20:55.223000 2020-07-18 13:05:55.425
#
#   TrackStatus Position  Deleted  DeletedReason  FastF1Generated  IsAccurate  \
# 0           1      NaN    False                           False       False
# 1           1      NaN    False                           False        True
# 2           1      NaN    False                           False        True
# 3           1      NaN    False                           False        True
# 4           1      NaN    False                           False        True
#
#    Year               gp_name
# 0  2020  Hungarian Grand Prix
# 1  2020  Hungarian Grand Prix
# 2  2020  Hungarian Grand Prix
# 3  2020  Hungarian Grand Prix
# 4  2020  Hungarian Grand Prix
#
# [5 rows x 33 columns]
# Weather data for Hungarian Grand Prix 2020:
#                     Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 0 0 days 00:01:00.953000     19.3      65.8     987.9     False       29.6
# 1 0 days 00:02:00.950000     19.3      66.6     987.8     False       29.4
# 2 0 days 00:03:00.954000     19.3      67.2     987.9     False       29.4
# 3 0 days 00:04:00.950000     19.4      67.2     987.9     False       29.4
# 4 0 days 00:05:00.952000     19.4      68.0     987.9     False       29.4
#
#    WindDirection  WindSpeed
# 0             99        1.1
# 1             95        0.8
# 2            109        0.7
# 3            159        1.4
# 4             96        1.2
# Processed DataFrame shape: (228, 25)
# Processed DataFrame shape: (228, 26)
# Processed DataFrame shape: (228, 27)
# Final shapes after filtering: [(166, 25), (166, 26), (166, 27)]
# Loaded qualifying data for Hungarian Grand Prix 2020
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2020/4/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "C:\Users\divya\anaconda3\Lib\site-packages\urllib3\connectionpool.py", line 789, in urlopen
#     response = self._make_request(
#                ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\divya\anaconda3\Lib\site-packages\urllib3\connectionpool.py", line 536, in _make_request
#     response = conn.getresponse()
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\divya\anaconda3\Lib\site-packages\urllib3\connection.py", line 464, in getresponse
#     httplib_response = super().getresponse()
#                        ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\divya\anaconda3\Lib\http\client.py", line 1428, in getresponse
#     response.begin()
#   File "C:\Users\divya\anaconda3\Lib\http\client.py", line 331, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\divya\anaconda3\Lib\http\client.py", line 300, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\divya\anaconda3\Lib\site-packages\requests\adapters.py", line 589, in send
#     resp = conn.urlopen(
#            ^^^^^^^^^^^^^
#   File "C:\Users\divya\anaconda3\Lib\site-packages\urllib3\connectionpool.py", line 843, in urlopen
#     retries = retries.increment(
#               ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\divya\anaconda3\Lib\site-packages\urllib3\util\retry.py", line 474, in increment
#     raise reraise(type(error), error, _stacktrace)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\divya\anaconda3\Lib\site-packages\urllib3\util\util.py", line 38, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\divya\anaconda3\Lib\site-packages\urllib3\connectionpool.py", line 789, in urlopen
#     response = self._make_request(
#                ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\divya\anaconda3\Lib\site-packages\urllib3\connectionpool.py", line 536, in _make_request
#     response = conn.getresponse()
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\divya\anaconda3\Lib\site-packages\urllib3\connection.py", line 464, in getresponse
#     httplib_response = super().getresponse()
#                        ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\divya\anaconda3\Lib\http\client.py", line 1428, in getresponse
#     response.begin()
#   File "C:\Users\divya\anaconda3\Lib\http\client.py", line 331, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\divya\anaconda3\Lib\http\client.py", line 300, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\divya\anaconda3\Lib\site-packages\requests_cache\session.py", line 286, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\divya\anaconda3\Lib\site-packages\requests_cache\session.py", line 254, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\divya\anaconda3\Lib\site-packages\fastf1\req.py", line 136, in send
#     return super().send(request, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\divya\anaconda3\Lib\site-packages\requests\sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\divya\anaconda3\Lib\site-packages\requests\adapters.py", line 604, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '16', '4', '18', '55', '3', '31', '5', '10', '23', '27', '26', '63', '20', '99', '7', '8', '6']
# C:\Users\divya\Downloads\QueBridge\data_loader.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['LapTime'] = df['LapTime'].dt.total_seconds().astype(float).round(3)
# C:\Users\divya\Downloads\QueBridge\data_loader.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(subset=['Time'], keep='first', inplace=True)
# C:\Users\divya\Downloads\QueBridge\data_loader.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['LapTime'] = df['LapTime'].dt.total_seconds().astype(float).round(3)
# C:\Users\divya\Downloads\QueBridge\data_loader.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(subset=['Time'], keep='first', inplace=True)
# C:\Users\divya\Downloads\QueBridge\data_loader.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['LapTime'] = df['LapTime'].dt.total_seconds().astype(float).round(3)
# C:\Users\divya\Downloads\QueBridge\data_loader.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(subset=['Time'], keep='first', inplace=True)
# core           INFO 	Loading data for 70th Anniversary Grand Prix - Qualifying [v3.4.4]
# Laps data for British Grand Prix 2020:
#                     Time Driver DriverNumber                LapTime  \
# 0 0 days 00:21:24.378000    HAM           44                    NaT
# 1 0 days 00:22:50.809000    HAM           44 0 days 00:01:26.431000
# 2 0 days 00:25:24.072000    HAM           44                    NaT
# 3 0 days 00:26:49.972000    HAM           44 0 days 00:01:25.900000
# 4 0 days 00:28:38.302000    HAM           44 0 days 00:01:48.330000
#
#    LapNumber  Stint             PitOutTime              PitInTime  \
# 0        1.0    1.0 0 days 00:19:14.428000                    NaT
# 1        2.0    1.0                    NaT                    NaT
# 2        3.0    1.0                    NaT                    NaT
# 3        4.0    1.0                    NaT                    NaT
# 4        5.0    1.0                    NaT 0 days 00:28:32.097000
#
#              Sector1Time            Sector2Time  ...           LapStartTime  \
# 0                    NaT 0 days 00:00:54.093000  ... 0 days 00:19:14.428000
# 1 0 days 00:00:28.005000 0 days 00:00:34.727000  ... 0 days 00:21:24.378000
# 2 0 days 00:00:49.962000 0 days 00:01:08.308000  ... 0 days 00:22:50.809000
# 3 0 days 00:00:27.886000 0 days 00:00:34.515000  ... 0 days 00:25:24.072000
# 4 0 days 00:00:33.029000 0 days 00:00:47.334000  ... 0 days 00:26:49.972000
#
#              LapStartDate TrackStatus Position  Deleted  DeletedReason  \
# 0 2020-08-01 13:04:14.467           1      NaN    False
# 1 2020-08-01 13:06:24.417           1      NaN    False
# 2 2020-08-01 13:07:50.848           1      NaN    False
# 3 2020-08-01 13:10:24.111           1      NaN    False
# 4 2020-08-01 13:11:50.011           1      NaN    False
#
#    FastF1Generated  IsAccurate  Year             gp_name
# 0            False       False  2020  British Grand Prix
# 1            False        True  2020  British Grand Prix
# 2            False       False  2020  British Grand Prix
# 3            False        True  2020  British Grand Prix
# 4            False       False  2020  British Grand Prix
#
# [5 rows x 33 columns]
# Weather data for British Grand Prix 2020:
#                     Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 0 0 days 00:00:18.196000     22.2      53.9     997.7     False       38.1
# 1 0 days 00:01:18.176000     22.3      52.4     997.7     False       38.7
# 2 0 days 00:02:18.203000     22.4      52.3     997.7     False       38.9
# 3 0 days 00:03:18.205000     22.5      51.8     997.7     False       39.3
# 4 0 days 00:04:18.212000     22.8      51.4     997.7     False       39.7
#
#    WindDirection  WindSpeed
# 0            215        3.6
# 1            210        3.3
# 2            200        3.3
# 3            192        3.0
# 4            207        3.8
# Processed DataFrame shape: (190, 25)
# Processed DataFrame shape: (190, 26)
# Processed DataFrame shape: (190, 27)
# Final shapes after filtering: [(142, 25), (142, 26), (142, 27)]
# Loaded qualifying data for British Grand Prix 2020
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['77', '44', '27', '33', '3', '18', '10', '16', '23', '4', '31', '5', '55', '8', '63', '26', '20', '6', '99', '7']
# C:\Users\divya\Downloads\QueBridge\data_loader.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['LapTime'] = df['LapTime'].dt.total_seconds().astype(float).round(3)
# C:\Users\divya\Downloads\QueBridge\data_loader.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(subset=['Time'], keep='first', inplace=True)
# C:\Users\divya\Downloads\QueBridge\data_loader.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['LapTime'] = df['LapTime'].dt.total_seconds().astype(float).round(3)
# C:\Users\divya\Downloads\QueBridge\data_loader.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(subset=['Time'], keep='first', inplace=True)
# C:\Users\divya\Downloads\QueBridge\data_loader.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['LapTime'] = df['LapTime'].dt.total_seconds().astype(float).round(3)
# C:\Users\divya\Downloads\QueBridge\data_loader.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(subset=['Time'], keep='first', inplace=True)
# core           INFO 	Loading data for Spanish Grand Prix - Qualifying [v3.4.4]
# Laps data for 70th Anniversary Grand Prix 2020:
#                     Time Driver DriverNumber                LapTime  \
# 0 0 days 00:21:27.461000    BOT           77                    NaT
# 1 0 days 00:22:54.636000    BOT           77 0 days 00:01:27.175000
# 2 0 days 00:25:18.729000    BOT           77 0 days 00:02:24.093000
# 3 0 days 00:26:45.728000    BOT           77 0 days 00:01:26.999000
# 4 0 days 00:28:31.537000    BOT           77 0 days 00:01:45.809000
#
#    LapNumber  Stint             PitOutTime              PitInTime  \
# 0        1.0    1.0 0 days 00:19:11.123000                    NaT
# 1        2.0    1.0                    NaT                    NaT
# 2        3.0    1.0                    NaT                    NaT
# 3        4.0    1.0                    NaT                    NaT
# 4        5.0    1.0                    NaT 0 days 00:28:25.635000
#
#              Sector1Time            Sector2Time  ...           LapStartTime  \
# 0                    NaT 0 days 00:00:59.717000  ... 0 days 00:19:11.123000
# 1 0 days 00:00:27.900000 0 days 00:00:35.589000  ... 0 days 00:21:27.461000
# 2 0 days 00:00:36.893000 0 days 00:00:59.769000  ... 0 days 00:22:54.636000
# 3 0 days 00:00:27.752000 0 days 00:00:35.382000  ... 0 days 00:25:18.729000
# 4 0 days 00:00:33.836000 0 days 00:00:43.828000  ... 0 days 00:26:45.728000
#
#              LapStartDate TrackStatus Position  Deleted  DeletedReason  \
# 0 2020-08-08 13:04:11.161           1      NaN    False
# 1 2020-08-08 13:06:27.499           1      NaN    False
# 2 2020-08-08 13:07:54.674           1      NaN    False
# 3 2020-08-08 13:10:18.767           1      NaN    False
# 4 2020-08-08 13:11:45.766           1      NaN    False
#
#    FastF1Generated  IsAccurate  Year                      gp_name
# 0            False       False  2020  70th Anniversary Grand Prix
# 1            False        True  2020  70th Anniversary Grand Prix
# 2            False        True  2020  70th Anniversary Grand Prix
# 3            False        True  2020  70th Anniversary Grand Prix
# 4            False       False  2020  70th Anniversary Grand Prix
#
# [5 rows x 33 columns]
# Weather data for 70th Anniversary Grand Prix 2020:
#                     Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 0 0 days 00:00:24.634000     26.4      52.8    1003.6     False       43.5
# 1 0 days 00:01:24.627000     26.4      52.8    1003.6     False       43.4
# 2 0 days 00:02:24.625000     26.4      52.9    1003.5     False       43.3
# 3 0 days 00:03:24.643000     26.3      52.8    1003.7     False       43.4
# 4 0 days 00:04:24.623000     26.2      52.8    1003.6     False       43.6
#
#    WindDirection  WindSpeed
# 0             26        3.9
# 1             15        3.3
# 2             28        4.3
# 3             24        4.7
# 4             21        4.6
# Processed DataFrame shape: (172, 25)
# Processed DataFrame shape: (172, 26)
# Processed DataFrame shape: (172, 27)
# Final shapes after filtering: [(128, 25), (128, 26), (128, 27)]
# Loaded qualifying data for 70th Anniversary Grand Prix 2020
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2020/6/qualifying.json failed; using cached response
# Traceback (most recent call last):
#   File "C:\Users\divya\anaconda3\Lib\site-packages\urllib3\connectionpool.py", line 789, in urlopen
#     response = self._make_request(
#                ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\divya\anaconda3\Lib\site-packages\urllib3\connectionpool.py", line 536, in _make_request
#     response = conn.getresponse()
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\divya\anaconda3\Lib\site-packages\urllib3\connection.py", line 464, in getresponse
#     httplib_response = super().getresponse()
#                        ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\divya\anaconda3\Lib\http\client.py", line 1428, in getresponse
#     response.begin()
#   File "C:\Users\divya\anaconda3\Lib\http\client.py", line 331, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\divya\anaconda3\Lib\http\client.py", line 300, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\divya\anaconda3\Lib\site-packages\requests\adapters.py", line 589, in send
#     resp = conn.urlopen(
#            ^^^^^^^^^^^^^
#   File "C:\Users\divya\anaconda3\Lib\site-packages\urllib3\connectionpool.py", line 843, in urlopen
#     retries = retries.increment(
#               ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\divya\anaconda3\Lib\site-packages\urllib3\util\retry.py", line 474, in increment
#     raise reraise(type(error), error, _stacktrace)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\divya\anaconda3\Lib\site-packages\urllib3\util\util.py", line 38, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\divya\anaconda3\Lib\site-packages\urllib3\connectionpool.py", line 789, in urlopen
#     response = self._make_request(
#                ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\divya\anaconda3\Lib\site-packages\urllib3\connectionpool.py", line 536, in _make_request
#     response = conn.getresponse()
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\divya\anaconda3\Lib\site-packages\urllib3\connection.py", line 464, in getresponse
#     httplib_response = super().getresponse()
#                        ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\divya\anaconda3\Lib\http\client.py", line 1428, in getresponse
#     response.begin()
#   File "C:\Users\divya\anaconda3\Lib\http\client.py", line 331, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\divya\anaconda3\Lib\http\client.py", line 300, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\divya\anaconda3\Lib\site-packages\requests_cache\session.py", line 286, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\divya\anaconda3\Lib\site-packages\requests_cache\session.py", line 254, in _send_and_cache
#     response = super().send(request, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\divya\anaconda3\Lib\site-packages\fastf1\req.py", line 136, in send
#     return super().send(request, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\divya\anaconda3\Lib\site-packages\requests\sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
#
#    Pressure  Rainfall  TrackTemp  WindDirection  WindSpeed
# 0     940.5     False       48.1            244        1.7
# 1     940.5     False       49.2             39        1.4
# 2     940.6     False       48.4            247        1.3
# 3     940.5     False       48.8            249        1.5
# 4     940.8     False       48.7             75        1.0
#
# [5 rows x 25 columns]
# Final merged data for D2:
#                     Time Driver  LapTime            Sector1Time Compound  \
# 0 0 days 00:52:40.951000    ALB   63.746 0 days 00:00:16.167000     SOFT
# 1 0 days 01:05:50.191000    ALB   63.868 0 days 00:00:16.165000     SOFT
# 2 0 days 00:45:45.195000    ALB   64.464 0 days 00:00:16.411000     SOFT
# 3 0 days 01:12:44.902000    ALB   64.650 0 days 00:00:16.209000     SOFT
# 4 0 days 00:20:21.637000    ALB   64.661 0 days 00:00:16.429000     SOFT
#
#    TyreLife             Team  Year              gp_name  track_length_km  ...  \
# 0       2.0  Red Bull Racing  2020  Austrian Grand Prix            4.318  ...
# 1       2.0  Red Bull Racing  2020  Austrian Grand Prix            4.318  ...
# 17152      33   95.987         3       6.0    12  2024        1
# 17153      33   97.947         3       3.0    12  2024        1
# 17154      35   83.880         3       2.0     7  2024        1
# 17155      35   84.121         3       2.0     7  2024        1
# 17156      35  114.429         3       3.0     7  2024        1
#
#        track_length_km  no_of_corners  longest_straight_m  ...  \
# 0                4.318           10.0               868.0  ...
# 1                4.318           10.0               868.0  ...
# 2                4.318           10.0               868.0  ...
# 3                4.318           10.0               868.0  ...
# 4                4.318           10.0               868.0  ...
# ...                ...            ...                 ...  ...
# 17152            5.281           16.0              1200.0  ...
# 17153            5.281           16.0              1200.0  ...
# 17154            5.281           16.0              1200.0  ...
# 17155            5.281           16.0              1200.0  ...
# 17156            5.281           16.0              1200.0  ...
#
#        sector_complexity  cornering_index  track_type_encoded  AirTemp  \
# 0                  0.431            19.00                 3.0     24.4
# 1                  0.431            19.00                 3.0     25.1
# 2                  0.431            19.00                 3.0     24.6
# 3                  0.431            19.00                 3.0     24.8
# 4                  0.431            19.00                 3.0     24.8
# ...                  ...              ...                 ...      ...
# 17152              0.355            10.63                 5.0     25.9
# 17153              0.355            10.63                 5.0     25.7
# 17154              0.355            10.63                 5.0     25.9
# 17155              0.355            10.63                 5.0     25.9
# 17156              0.355            10.63                 5.0     26.0
#
#        Humidity  Pressure  Rainfall  TrackTemp  WindDirection  WindSpeed
# 0          34.5     940.5         0       48.1            244        1.7
# 1          34.0     940.5         0       49.2             39        1.4
# 2          33.7     940.6         0       48.4            247        1.3
# 3          34.6     940.5         0       48.8            249        1.5
# 4          34.1     940.8         0       48.7             75        1.0
# ...         ...       ...       ...        ...            ...        ...
# 17152      66.0    1017.2         0       29.7            281        1.5
# 17153      63.0    1017.6         0       29.1              0        1.9
# 17154      66.0    1017.2         0       29.8            310        1.2
# 17155      64.0    1017.3         0       30.2            267        2.0
# 17156      64.0    1017.2         0       30.1            274        1.7
#
# [17157 rows x 24 columns]

# %%
LDF=Pre

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# %%
# Define features (X) and target (y)
y = LDF["LapTime"]
X = LDF.drop(columns=["LapTime"])  # Keep all relevant features

# Identify categorical columns
categorical_cols = ['Driver']

# Convert categorical columns to 'category' typE

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42, shuffle=True)
for col in categorical_cols:
    X_train[col] = X_train[col].astype('category')
    X_test[col] = X_test[col].astype('category')

model = xgb.XGBRegressor(
    objective="reg:squarederror",
    n_estimators=100,
    max_depth=6,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    enable_categorical=True  # Enable support for categorical features
)

# Train the model
model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=6, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
y_pred = model.predict(X_test)

# %%
# Calculate performance metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error (MAE): {mae:.4f} sec")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f} sec")
print(f"R² Score: {r2:.4f}")  # Closer to 1 = better model

print(f"Training Score: {model.score(X_train, y_train):.4f}")
print(f"Test Score: {model.score(X_test, y_test):.4f}")
# Out:
# Mean Absolute Error (MAE): 5.1964 sec
# Mean Squared Error (MSE): 52.9402
# Root Mean Squared Error (RMSE): 7.2760 sec
# R² Score: 0.7848
# Training Score: 0.8705
# Test Score: 0.7848

# %%
train_score = model.score(X_train, y_train)  # Training accuracy
test_score = model.score(X_test, y_test)    # Test accuracy

print(f"Training Accuracy: {train_score:.4f}")
print(f"Test Accuracy: {test_score:.4f}")
# Out:
# Training Accuracy: 0.8705
# Test Accuracy: 0.7848

# %%
correlation_matrix = LDF.corr()
print(correlation_matrix["LapTime"].sort_values(ascending=False))
# Out:
# LapTime                       1.000000
# track_length_km               0.590689
# longest_straight_m            0.430250
# no_of_corners                 0.404719
# Humidity                      0.234439
# track_type_encoded            0.190801
# Pressure                      0.174955
# WindDirection                 0.158479
# TyreLife                      0.141786
# straight_to_corner_ratio      0.091361
# Rainfall                      0.046361
# WindSpeed                     0.043919
# Driver                        0.014550
# elevation_change_m           -0.002581
# Team                         -0.021979
# gp_name                      -0.037720
# technical_difficulty_score   -0.038020
# sector_complexity            -0.056113
# AirTemp                      -0.062583
# Compound                     -0.180577
# elevation_challenge_score    -0.193662
# TrackTemp                    -0.265415
# cornering_index              -0.377462
# Name: LapTime, dtype: float64

# %%
from sklearn.model_selection import learning_curve
import matplotlib.pyplot as plt
import numpy as np


train_mean = np.mean(train_score)
test_mean = np.mean(test_score)

plt.figure(figsize=(8, 5))
plt.plot(train_size, train_mean, 'o-', label="Training Score")
plt.plot(train_size, val_mean, 'o-', label="Validation Score")
plt.xlabel("Training Set Size")
plt.ylabel("R² Score")
plt.title("Learning Curve")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 10
#       7 test_mean = np.mean(test_score)
#       9 plt.figure(figsize=(8, 5))
# ---> 10 plt.plot(train_size, train_mean, 'o-', label="Training Score")
#      11 plt.plot(train_size, val_mean, 'o-', label="Validation Score")
#      12 plt.xlabel("Training Set Size")
#
# NameError: name 'train_size' is not defined

# %%
# Get feature importance
importances = model.feature_importances_
features = X_train.columns

# Sort by importance
indices = np.argsort(importances)[::-1]

# Plot
plt.figure(figsize=(10, 5))
plt.title("Feature Importances")
plt.bar(range(len(features)), importances[indices], align="center")
plt.xticks(range(len(features)), [features[i] for i in indices], rotation=90)
plt.show()

# %%
# Generate learning curve data
train_sizes, train_scores, test_scores = learning_curve(
    estimator=model,
    X=X_train,  # Replace with your training features
    y=y_train,  # Replace with your training target
    cv=5,       # Number of cross-validation folds
    scoring="r2",  # Use R² score as the metric
    train_sizes=np.linspace(0.1, 1.0, 10)  # Training set sizes to evaluate
)

# Compute means and standard deviations
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# Plot the learning curve
plt.figure(figsize=(8, 5))
plt.plot(train_sizes, train_mean, 'o-', color="blue", label="Training Score")
plt.plot(train_sizes, test_mean, 'o-', color="orange", label="Validation Score")

# Add shaded regions for standard deviation
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, alpha=0.2, color="blue")
plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, alpha=0.2, color="orange")

# Add labels and title
plt.xlabel("Training Set Size")
plt.ylabel("R² Score")
plt.title("Learning Curve")
plt.legend(loc="best")
plt.grid(True)  # Add grid lines for better readability

# Show the plot

# %%
import pickle

# Assuming 'model' is your trained model
with open('model.pkl', 'wb') as f:
    pickle.dump(model, f)
